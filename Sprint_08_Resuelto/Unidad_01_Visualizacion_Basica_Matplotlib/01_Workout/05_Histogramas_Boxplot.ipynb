# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Visualización con Matplotlib: Histogramas y diagramas de caja

# %% [markdown]
# Vamos a ver de forma sencilla como hacer los gráficos que nos generaban las funciones que empleamos en las visualizaciones analiticas del sprint anteior. En concreto, veremos los histogramas y los boxplots:

# %%
#%matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

data = np.random.randn(1000)

# %% [markdown]
# ### Histogramas

# %% [markdown]
# Tan sencillo como:

# %%
plt.hist(data)
# Out:
# (array([  9.,  25.,  82., 140., 231., 232., 163.,  87.,  23.,   8.]),
#  array([-3.10940196, -2.50517002, -1.90093809, -1.29670615, -0.69247421,
#         -0.08824227,  0.51598967,  1.12022161,  1.72445355,  2.32868549,
#          2.93291742]),
#  <BarContainer object of 10 artists>)

# %%
fig = plt.figure(figsize = (4.5,3))
ax = plt.axes()
ax.hist(data)
# Out:
# (array([  9.,  25.,  82., 140., 231., 232., 163.,  87.,  23.,   8.]),
#  array([-3.10940196, -2.50517002, -1.90093809, -1.29670615, -0.69247421,
#         -0.08824227,  0.51598967,  1.12022161,  1.72445355,  2.32868549,
#          2.93291742]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# La función ``hist()`` tiene muchas opciones para ajustar tanto el cálculo como la visualización; aquí tienes un ejemplo de un histograma más personalizado (en el que tocamos el número de columnas `bins`, la transparencia y el color):

# %%
plt.hist(data,
         bins = 50,
         alpha = 0.7,
         color = "steelblue"
         );

# %% [markdown]
# La transparencia es particularmente interesante para comparar histogramas o mostrar dicha comparación (y aprovecho para enseñarte un truco para cuando tengas argumentos repetidos que poner en tus llamadas a función):

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(alpha = 0.3, bins = 20)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
# Out:
# (array([  1.,   3.,   4.,   5.,  13.,  30.,  43.,  81.,  94., 137., 171.,
#         136., 110.,  74.,  49.,  19.,  18.,   8.,   3.,   1.]),
#  array([-4.62692016, -3.90000945, -3.17309874, -2.44618804, -1.71927733,
#         -0.99236662, -0.26545592,  0.46145479,  1.18836549,  1.9152762 ,
#          2.64218691,  3.36909761,  4.09600832,  4.82291902,  5.54982973,
#          6.27674044,  7.00365114,  7.73056185,  8.45747255,  9.18438326,
#          9.91129397]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# Es también el momento de enseñarte a capturar los límites de esos bines:

# %%
fig = plt.Figure()
ax = plt.axes()
limites = ax.hist(x1,alpha = 0.3, bins = 30)

# %% [markdown]
# Limites es una tupla en la que el primer valor son los conteos y el segundo los límites de las barras:

# %%
limites[0]
# Out:
# array([ 2.,  3.,  2.,  2.,  6.,  9., 15., 24., 25., 58., 59., 63., 73.,
#        88., 77., 77., 73., 82., 72., 57., 39., 26., 30., 13.,  8.,  9.,
#         0.,  3.,  3.,  2.])

# %%
limites[1]
# Out:
# array([-2.55135925, -2.38098833, -2.2106174 , -2.04024648, -1.86987555,
#        -1.69950463, -1.5291337 , -1.35876277, -1.18839185, -1.01802092,
#        -0.84765   , -0.67727907, -0.50690815, -0.33653722, -0.16616629,
#         0.00420463,  0.17457556,  0.34494648,  0.51531741,  0.68568833,
#         0.85605926,  1.02643019,  1.19680111,  1.36717204,  1.53754296,
#         1.70791389,  1.87828481,  2.04865574,  2.21902666,  2.38939759,
#         2.55976852])

# %% [markdown]
# ### Boxplots
#
# Los diagramas de caja eran esos diagramas en los que resumíamos las medidas de posición y añadíamos una posible formar de obtener valores anómalos, extremos o outliers. En forma de diagrama:

# %% [markdown]
# ```text
#      Q1-1.5IQR   Q1  mediana  Q3   Q3+1.5IQR
#                   |-----:-----|
#   o      |--------|     :     |--------|    o  o
#                   |-----:-----|
# flier             <----------->            fliers/outlier
#                        IQR
#
# ```

# %% [markdown]
# Donde IQR es el rango intercuartilico (la diferencia entre el valor de Q3 o tercer cuartil o percentil-75 y el valor de Q1 o primer cuartil, o percentil-25)

# %% [markdown]
# En matplotlib:

# %%
plt.boxplot(data, whis = 1.5)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27732bea0d0>,
#   <matplotlib.lines.Line2D at 0x27732bea210>],
#  'caps': [<matplotlib.lines.Line2D at 0x27732bea350>,
#   <matplotlib.lines.Line2D at 0x27732bea490>],
#  'boxes': [<matplotlib.lines.Line2D at 0x27732be9f90>],
#  'medians': [<matplotlib.lines.Line2D at 0x27732bea5d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27732bea710>],
#  'means': []}

# %% [markdown]
# En el caso de matplotlib empleamos por defecto diagramas de caja verticales. Pero podemos cambiarlo:

# %%
plt.boxplot(data, vert = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27732c61950>,
#   <matplotlib.lines.Line2D at 0x27732c61a90>],
#  'caps': [<matplotlib.lines.Line2D at 0x27732c61bd0>,
#   <matplotlib.lines.Line2D at 0x27732c61d10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x27732c61810>],
#  'medians': [<matplotlib.lines.Line2D at 0x27732c61e50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27732c61f90>],
#  'means': []}

# %% [markdown]
# Y podemos mostrar varios juntos:

# %%
plt.boxplot([x1,x2,x3])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27735744f50>,
#   <matplotlib.lines.Line2D at 0x27735745090>,
#   <matplotlib.lines.Line2D at 0x27735745810>,
#   <matplotlib.lines.Line2D at 0x27735745950>,
#   <matplotlib.lines.Line2D at 0x27732ccead0>,
#   <matplotlib.lines.Line2D at 0x27735598e10>],
#  'caps': [<matplotlib.lines.Line2D at 0x277357451d0>,
#   <matplotlib.lines.Line2D at 0x27735745310>,
#   <matplotlib.lines.Line2D at 0x27735745a90>,
#   <matplotlib.lines.Line2D at 0x27735745bd0>,
#   <matplotlib.lines.Line2D at 0x27735745f90>,
#   <matplotlib.lines.Line2D at 0x277357460d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x27735744e10>,
#   <matplotlib.lines.Line2D at 0x277357456d0>,
#   <matplotlib.lines.Line2D at 0x27732ccd310>],
#  'medians': [<matplotlib.lines.Line2D at 0x27735745450>,
#   <matplotlib.lines.Line2D at 0x27735745d10>,
#   <matplotlib.lines.Line2D at 0x27735746210>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27735745590>,
#   <matplotlib.lines.Line2D at 0x27735745e50>,
#   <matplotlib.lines.Line2D at 0x27735746350>],
#  'means': []}
